# %%
import pandas as pd 
#from autoviz import data_cleaning_suggestions
path = r"C:\Users\HP\Desktop\Untitled Folder 3\housing.csv"
df = pd.read_csv(path)
#data_cleaning_suggestions(df)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
max_thresold=df["median_income"].quantile(0.95)
max_thresold
# Out:
# 7.300305

# %%
min_thresold=df["median_income"].quantile(0.05)
min_thresold
# Out:
# 1.60057

# %%
df[df["median_income"]<min_thresold]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20       -122.27     37.85                40.0        751.0           184.0
# 33       -122.27     37.83                49.0       1655.0           366.0
# 35       -122.27     37.83                49.0       1215.0           282.0
# 36       -122.27     37.83                48.0       1798.0           432.0
# 37       -122.28     37.83                52.0       1511.0           390.0
# ...          ...       ...                 ...          ...             ...
# 20610    -121.56     39.10                28.0       2130.0           484.0
# 20611    -121.55     39.10                27.0       1783.0           441.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20613    -121.55     39.09                31.0       1728.0           365.0
# 20635    -121.09     39.48                25.0       1665.0           374.0
#
# ...

# %%
df[df["median_income"]>max_thresold]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 126      -122.22     37.84                50.0       2935.0           473.0
# 128      -122.21     37.83                40.0       4991.0           674.0
# 131      -122.19     37.84                18.0       1617.0           210.0
# ...          ...       ...                 ...          ...             ...
# 20436    -118.69     34.21                10.0       3663.0           409.0
# 20442    -118.78     34.25                13.0       1841.0           237.0
# 20487    -118.67     34.30                 5.0       6123.0           825.0
# 20503    -118.75     34.33                27.0        534.0            85.0
# 20504    -118.73     34.29                11.0       5451.0           736.0
#
# ...

# %%
df[(df["median_income"]<max_thresold)& (df["median_income"]>min_thresold)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# ...          ...       ...                 ...          ...             ...
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
